# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d = pd.read_csv('./ZestyAI-combined_structure_status.csv')

# %%
d.head()
# Out:
#              DAMAGE STREETNUMB STREETNAME STREETTYPE STREETSUFF  \
# 0  Destroyed (>50%)       1480    Patrick      Drive        154
# 1  Destroyed (>50%)       1480    Patrick      Drive        156
# 2  Destroyed (>50%)       1480    Patrick      Drive        158
# 3  Destroyed (>50%)       1480    Patrick      Drive        160
# 4   Affected (1-9%)       1480    Patrick      Drive        162
#
#                    CITY STATE CALFIREUNI COUNTY COMMUNITY  ...   TOPOGRAPHY  \
# 0  Paradise Northwest A    CA        BTU  Butte  Paradise  ...  Flat Ground
# 1  Paradise Northwest A    CA        BTU  Butte  Paradise  ...  Flat Ground
# 2  Paradise Northwest A    CA        BTU  Butte  Paradise  ...  Flat Ground
# 3  Paradise Northwest A    CA        BTU  Butte  Paradise  ...  Flat Ground
# 4  Paradise Northwest A    CA        BTU  Butte  Paradise  ...  Flat Ground
#
#                APN ASSESSEDIM YEARBUILT  \
# 0  050-150-111-000    2756731    1900.0
# ...

# %%
d['DAMAGE'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
d.loc[d['DAMAGE']=='Destroyed (>50%)','DAMAGE'] = 'Destroyed'
d.loc[d['DAMAGE']=='Affected (1-9%)','DAMAGE'] = 'Affected'
d.loc[d['DAMAGE']=='1-9%','DAMAGE'] = 'Affected'
d.loc[d['DAMAGE']=='Minor (10-25%)','DAMAGE'] = 'Minor'
d.loc[d['DAMAGE']=='10-25%','DAMAGE'] = 'Minor'
d.loc[d['DAMAGE']=='Major (26-50%)','DAMAGE'] = 'Major'
d.loc[d['DAMAGE']=='26-50%','DAMAGE'] = 'Major'
d.loc[d['DAMAGE']=='51-75%','DAMAGE'] = 'Destroyed'

# %%
d['DAMAGE'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.scatter(d.DAMAGE, d.CLAIM)

# %%
d['VEGCLEARAN'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
d.loc[d['VEGCLEARAN']=="0-30'",'VEGCLEARAN'] = '0-30'
d.loc[d['VEGCLEARAN']=="30-100'",'VEGCLEARAN'] = '30-100'
d.loc[d['VEGCLEARAN']==">100'",'VEGCLEARAN'] = '>100'
d.loc[d['VEGCLEARAN']=="Unknown",'VEGCLEARAN'] = 'unknown'
d.loc[d['VEGCLEARAN']=="-",'VEGCLEARAN'] = 'unknown'
d['VEGCLEARAN'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
d.ASSESSEDIM.tail()
# Out:
# 31679    20679
# 31680    20679
# 31681    35000
# 31682    30939
# 31683    30969
# Name: ASSESSEDIM, dtype: int64
